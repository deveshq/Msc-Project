# %% [markdown]
# <table>
#   <tr>
#     <th>Error</th>
#     <th>H-Cz CNOT (A)</th>
#     <th>H-Cz CNOT (B)</th>
#     <th>AS CNOT</th>
#   </tr>
#   <tr>
#     <td>No Error</td>
#     <td>1.0</td>
#     <td>1.0</td>
#     <td>1.0</td>
#   </tr>
#   <tr>
#     <td>Error 1</td>
#     <td>0.97225</td>
#     <td>0.981749</td>
#     <td>0.99925</td>
#   </tr>
#   <tr>
#     <td>Error 2</td>
#     <td>0.91000</td>
#     <td>0.91975</td>
#     <td>0.93675</td>
#   </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#     <td>CNOT Protocol</td>
#     <td>H-Cz CNOT (A)</td>
#     <td>H-Cz CNOT (B)</td>
#     <td>AS CNOT</td>
#   </tr>
#   <tr>
#     <td>Obtained F</td>
#     <td>1.0</td>
#     <td>1.0</td>
#     <td>1.0</td>
#   </tr>
# </table>

# %% [markdown]
# Error set η ϵ ϵ
# ′
# T
# 1 10−6 0.5 × 10−5 2.5 × 10−5 50
# 2 10−6 0.01 0.05 50

# %% [markdown]
# <table>
#   <tr>
#     <th colspan='5'>Error Parameters</th>
#   </tr>
#   <tr>
#     <th>Set</th>
#     <th>η</th>
#     <th>ϵ</th>
#     <th>ϵ'</th>
#     <th>T (µk)</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>$10^{-6}$</td>
#     <td>$0.5 \times$$10^{-5}$</td>
#     <td>$2.5 \times$$10^{-5}$</td>
#     <td>$50$</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>$10^{-6}$</td>
#     <td>$0.01$</td>
#     <td>$0.05$</td>
#     <td>$50$</td>
#   </tr>
# </table>

# %%
import qiskit
from qiskit import *

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)
a = qc.draw('mpl')

# %%
a.savefig("Ent.jpg",dpi=1080)

# %%
help(a.savefig)
# Out:
# Help on method savefig in module matplotlib.figure:
#
# savefig(fname, *, transparent=None, **kwargs) method of matplotlib.figure.Figure instance
#     Save the current figure.
#
#     Call signature::
#
#       savefig(fname, *, dpi='figure', format=None, metadata=None,
#               bbox_inches=None, pad_inches=0.1,
#               facecolor='auto', edgecolor='auto',
#               backend=None, **kwargs
#              )
#
#     The available output formats depend on the backend being used.
#
#     Parameters
#     ----------
#     fname : str or path-like or binary file-like
#         A path, or a Python file-like object, or
#         possibly some backend-dependent object such as
#         `matplotlib.backends.backend_pdf.PdfPages`.
#
#         If *format* is set, it determines the output format, and the file
#         is saved as *fname*.  Note that *fname* is used verbatim, and there
#         is no attempt to make the extension, if any, of *fname* match
# ...
